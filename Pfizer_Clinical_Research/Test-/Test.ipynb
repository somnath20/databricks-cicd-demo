# %%
df = spark.read.option("header", "true").csv(
    "abfss://ctms-landing@pfizerclinicaldata.dfs.core.windows.net/study_master/"
)
display(df)

# %%
# %sql
SELECT *
FROM clinical.bronze.study_master;

# %%
# %sql
SELECT *
FROM clinical.silver.study_master;
